# %%
import pandas as pd

# %%
pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
from datasets import load_dataset
dataset = load_dataset("divyabindu77/parleds", split="train")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# parle.json:   0%|          | 0.00/23.0k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/34 [00:00<?, ? examples/s]

# %%
df = dataset.to_pandas()

# %%
df
# Out:
#                                     input_instruction question_type  \
# 0       Generate 3 true/false questions on algorithms    True/False
# 1        Generate 2 true/false questions on databases    True/False
# 2   Generate 4 true/false questions on operating s...    True/False
# 3         Generate 5 true/false questions on networks    True/False
# 4                  Generate 3 MCQs on data structures           MCQ
# 5            Generate 4 MCQs on programming languages           MCQ
# 6   Generate 3 short answer questions on operating...  Short Answer
# 7      Generate 4 short answer questions on databases  Short Answer
# 8   Generate 2 short answer questions on computer ...  Short Answer
# 9   Generate 3 true/false questions on machine lea...    True/False
# 10   Generate 2 true/false questions on cybersecurity    True/False
# 11  Generate 4 true/false questions on programming...    True/False
# 12  Generate 5 true/false questions on cloud compu...    True/False
# ...

# %%
def formatting_prompts_func(row):
  return f"""<|start_header_id|>system<|end_header_id|>{row["input_instruction"]}<|eot_id|><|start_header_id|>user<|end_header_id|> This is the question: {row["question_type"]} {row["topic"]} <|eot_id|><|start_header_id|>assistant<|end_header_id|>{row["questions"]}<|eot_id|>"""

# %%
df = pd.DataFrame(df)

# %%
df['prompt'] = df.apply(formatting_prompts_func, axis=1)

# %%
df
# Out:
#                                     input_instruction question_type  \
# 0       Generate 3 true/false questions on algorithms    True/False
# 1        Generate 2 true/false questions on databases    True/False
# 2   Generate 4 true/false questions on operating s...    True/False
# 3         Generate 5 true/false questions on networks    True/False
# 4                  Generate 3 MCQs on data structures           MCQ
# 5            Generate 4 MCQs on programming languages           MCQ
# 6   Generate 3 short answer questions on operating...  Short Answer
# 7      Generate 4 short answer questions on databases  Short Answer
# 8   Generate 2 short answer questions on computer ...  Short Answer
# 9   Generate 3 true/false questions on machine lea...    True/False
# 10   Generate 2 true/false questions on cybersecurity    True/False
# 11  Generate 4 true/false questions on programming...    True/False
# 12  Generate 5 true/false questions on cloud compu...    True/False
# ...

# %%
import datasets
dataset = datasets.Dataset.from_pandas(df)
dataset.push_to_hub("divyabindu77/seekhan_final",token="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")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/divyabindu77/seekhan_final/commit/7e18762f9d53a653f6aff3b35a9c7606c703b561', commit_message='Upload dataset', commit_description='', oid='7e18762f9d53a653f6aff3b35a9c7606c703b561', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/divyabindu77/seekhan_final', endpoint='https://huggingface.co', repo_type='dataset', repo_id='divyabindu77/seekhan_final'), pr_revision=None, pr_num=None)
