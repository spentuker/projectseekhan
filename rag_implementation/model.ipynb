# %%
# !pip install langchain-community==0.2.4 langchain==0.2.3 faiss-cpu==1.8.0 unstructured==0.14.5 unstructured[pdf]==0.14.5 transformers==4.41.2 sentence-transformers==3.0.1
# Out:
# Requirement already satisfied: langchain-community==0.2.4 in c:\users\srujana\anaconda3\lib\site-packages (0.2.4)
# Requirement already satisfied: langchain==0.2.3 in c:\users\srujana\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: faiss-cpu==1.8.0 in c:\users\srujana\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: unstructured==0.14.5 in c:\users\srujana\anaconda3\lib\site-packages (0.14.5)
# Requirement already satisfied: transformers==4.41.2 in c:\users\srujana\anaconda3\lib\site-packages (4.41.2)
# Requirement already satisfied: sentence-transformers==3.0.1 in c:\users\srujana\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (3.11.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (0.6.7)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (1.23.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (2.28.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-community==0.2.4) (8.5.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\srujana\anaconda3\lib\site-packages (from langchain==0.2.3) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\srujana\anaconda3\lib\site-packages (from langchain==0.2.3) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\srujana\anaconda3\lib\site-packages (from langchain==0.2.3) (2.9.2)
# Requirement already satisfied: chardet in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (3.0.4)
# Requirement already satisfied: filetype in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (0.4.27)
# Requirement already satisfied: lxml in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (4.9.1)
# Requirement already satisfied: nltk in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (3.7)
# Requirement already satisfied: tabulate in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (0.8.10)
# Requirement already satisfied: beautifulsoup4 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (4.11.1)
# Requirement already satisfied: emoji in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (2.14.0)
# Requirement already satisfied: python-iso639 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (2024.10.22)
# Requirement already satisfied: langdetect in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (1.0.9)
# Requirement already satisfied: rapidfuzz in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (3.10.1)
# Requirement already satisfied: backoff in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (0.28.1)
# Requirement already satisfied: wrapt in c:\users\srujana\anaconda3\lib\site-packages (from unstructured==0.14.5) (1.14.1)
# Requirement already satisfied: filelock in c:\users\srujana\anaconda3\lib\site-packages (from transformers==4.41.2) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in c:\users\srujana\anaconda3\lib\site-packages (from transformers==4.41.2) (0.26.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\srujana\anaconda3\lib\site-packages (from transformers==4.41.2) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\srujana\anaconda3\lib\site-packages (from transformers==4.41.2) (2022.7.9)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\srujana\anaconda3\lib\site-packages (from transformers==4.41.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\srujana\anaconda3\lib\site-packages (from transformers==4.41.2) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\srujana\anaconda3\lib\site-packages (from transformers==4.41.2) (4.64.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\srujana\anaconda3\lib\site-packages (from sentence-transformers==3.0.1) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\srujana\anaconda3\lib\site-packages (from sentence-transformers==3.0.1) (1.2.1)
# Requirement already satisfied: scipy in c:\users\srujana\anaconda3\lib\site-packages (from sentence-transformers==3.0.1) (1.10.0)
# Requirement already satisfied: Pillow in c:\users\srujana\anaconda3\lib\site-packages (from sentence-transformers==3.0.1) (11.0.0)
# Requirement already satisfied: onnx in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (1.17.0)
# Requirement already satisfied: pdf2image in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (1.17.0)
# Requirement already satisfied: pdfminer.six in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (20231228)
# Requirement already satisfied: pikepdf in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (9.4.2)
# Requirement already satisfied: pillow-heif in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (0.21.0)
# Requirement already satisfied: pypdf in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (5.1.0)
# Requirement already satisfied: pytesseract in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (0.3.13)
# Requirement already satisfied: google-cloud-vision in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (3.8.1)
# Requirement already satisfied: effdet in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (0.4.1)
# Requirement already satisfied: unstructured-inference==0.7.33 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (0.7.33)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured[pdf]==0.14.5) (0.3.13)
# Requirement already satisfied: layoutparser in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (0.3.4)
# Requirement already satisfied: python-multipart in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (0.0.19)
# Requirement already satisfied: opencv-python!=4.7.0.68 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (4.10.0.84)
# Requirement already satisfied: onnxruntime>=1.17.0 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (1.20.1)
# Requirement already satisfied: matplotlib in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (3.7.0)
# Requirement already satisfied: timm in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (1.0.12)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\srujana\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.4) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\srujana\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.4) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\srujana\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.4) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\srujana\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.4) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\srujana\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.4) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\srujana\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.4) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\srujana\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.4) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\srujana\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.4) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\srujana\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.4) (0.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\srujana\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (2024.10.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\srujana\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community==0.2.4) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\srujana\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.4) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\srujana\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.4) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\srujana\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.4) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\srujana\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain==0.2.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\srujana\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain==0.2.3) (2.23.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\srujana\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.4) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\srujana\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.4) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\srujana\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.4) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\srujana\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community==0.2.4) (2022.12.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\srujana\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.2.4) (2.0.1)
# Requirement already satisfied: networkx in c:\users\srujana\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\srujana\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.1.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\srujana\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\srujana\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers==3.0.1) (1.2.1)
# Requirement already satisfied: colorama in c:\users\srujana\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.41.2) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\srujana\anaconda3\lib\site-packages (from beautifulsoup4->unstructured==0.14.5) (2.3.2.post1)
# Requirement already satisfied: torchvision in c:\users\srujana\anaconda3\lib\site-packages (from effdet->unstructured[pdf]==0.14.5) (0.20.1)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\srujana\anaconda3\lib\site-packages (from effdet->unstructured[pdf]==0.14.5) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in c:\users\srujana\anaconda3\lib\site-packages (from effdet->unstructured[pdf]==0.14.5) (2.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\users\srujana\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]==0.14.5) (2.24.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\users\srujana\anaconda3\lib\site-packages (from google-cloud-vision->unstructured[pdf]==0.14.5) (2.36.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\srujana\anaconda3\lib\site-packages (from google-cloud-vision->unstructured[pdf]==0.14.5) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\srujana\anaconda3\lib\site-packages (from google-cloud-vision->unstructured[pdf]==0.14.5) (5.29.1)
# Requirement already satisfied: six in c:\users\srujana\anaconda3\lib\site-packages (from langdetect->unstructured==0.14.5) (1.16.0)
# Requirement already satisfied: click in c:\users\srujana\anaconda3\lib\site-packages (from nltk->unstructured==0.14.5) (8.0.4)
# Requirement already satisfied: joblib in c:\users\srujana\anaconda3\lib\site-packages (from nltk->unstructured==0.14.5) (1.1.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\srujana\anaconda3\lib\site-packages (from pdfminer.six->unstructured[pdf]==0.14.5) (39.0.1)
# Requirement already satisfied: Deprecated in c:\users\srujana\anaconda3\lib\site-packages (from pikepdf->unstructured[pdf]==0.14.5) (1.2.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\srujana\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers==3.0.1) (2.2.0)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.14.5) (24.1.0)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.14.5) (0.2.0)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.14.5) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.14.5) (1.6.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\srujana\anaconda3\lib\site-packages (from unstructured-client->unstructured==0.14.5) (2.8.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\srujana\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[pdf]==0.14.5) (1.15.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\srujana\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]==0.14.5) (1.66.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\srujana\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]==0.14.5) (1.68.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\srujana\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[pdf]==0.14.5) (1.68.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\srujana\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]==0.14.5) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\srujana\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]==0.14.5) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\srujana\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]==0.14.5) (4.9)
# Requirement already satisfied: anyio in c:\users\srujana\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.4) (3.5.0)
# Requirement already satisfied: httpcore==1.* in c:\users\srujana\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.4) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\srujana\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.4) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\srujana\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain-community==0.2.4) (3.0.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\srujana\anaconda3\lib\site-packages (from omegaconf>=2.0->effdet->unstructured[pdf]==0.14.5) (4.9.3)
# Requirement already satisfied: coloredlogs in c:\users\srujana\anaconda3\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\srujana\anaconda3\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (24.3.25)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\srujana\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\srujana\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\srujana\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\srujana\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\srujana\anaconda3\lib\site-packages (from matplotlib->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (3.0.9)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\srujana\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.4) (0.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\srujana\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.1) (2.1.1)
# Requirement already satisfied: pandas in c:\users\srujana\anaconda3\lib\site-packages (from layoutparser->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (1.5.3)
# Requirement already satisfied: iopath in c:\users\srujana\anaconda3\lib\site-packages (from layoutparser->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (0.1.10)
# Requirement already satisfied: pdfplumber in c:\users\srujana\anaconda3\lib\site-packages (from layoutparser->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (0.11.4)
# Requirement already satisfied: pycparser in c:\users\srujana\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[pdf]==0.14.5) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\srujana\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[pdf]==0.14.5) (0.4.8)
# Requirement already satisfied: sniffio>=1.1 in c:\users\srujana\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.4) (1.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\srujana\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (10.0)
# Requirement already satisfied: portalocker in c:\users\srujana\anaconda3\lib\site-packages (from iopath->layoutparser->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (3.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\srujana\anaconda3\lib\site-packages (from pandas->layoutparser->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (2022.7)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\srujana\anaconda3\lib\site-packages (from pdfplumber->layoutparser->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (4.30.0)
# Requirement already satisfied: pyreadline3 in c:\users\srujana\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (3.5.4)
# Requirement already satisfied: pywin32>=226 in c:\users\srujana\anaconda3\lib\site-packages (from portalocker->iopath->layoutparser->unstructured-inference==0.7.33->unstructured[pdf]==0.14.5) (305.1)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

from langchain_community.llms import Ollama
from langchain.document_loaders import UnstructuredFileLoader
from langchain_community.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import RetrievalQA

# %%
# loading the LLM
llm = Ollama(
    model="laddo",
    temperature=0
)

# %%
# loading the document
loader = UnstructuredFileLoader("PP Unit 2 Tesseract.pdf")
documents = loader.load()

# %%
# create document chunks
text_splitter = CharacterTextSplitter(separator="/n",
                                      chunk_size=7500,
                                      chunk_overlap=200)

# %%
text_chunks = text_splitter.split_documents(documents)

# %%
embeddings = HuggingFaceEmbeddings()
# Out:
# C:\Users\Srujana\AppData\Local\Temp\ipykernel_19248\3655315981.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   embeddings = HuggingFaceEmbeddings()
# c:\Users\Srujana\anaconda3\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# c:\Users\Srujana\anaconda3\lib\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
knowledge_base = FAISS.from_documents(text_chunks, embeddings)

# %%
# retrieval QA chain
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=knowledge_base.as_retriever())

# %%
question = "What is this document about?"
response = qa_chain.invoke({"query": question})
print(response["result"])
# Out:
#   This document appears to be a guide on how to use the Message Passing Interface (MPI) for parallel computing, specifically focusing on Cartesian topology support in MPI. The document covers the following topics:
#
# 1. Initializing MPI and determining the size and rank of processes in a communicator.
# 2. Creating a Cartesian communicator using MPI_Cart_create() and defining the dimensions and periodicity of the grid.
# 3. Retrieving the coordinates of each process in the Cartesian grid using MPI_Cart_coords().
# 4. Performing point-to-point communication or collective operations specific to your application's grid structure, such as MPI_Send, MPI_Recv, and collective operations like MPI_Allreduce, MPI_Gather, or MPI_Scatter.
# 5. Freeing the Cartesian communicator after use using MPI_Comm_free().

# %%
question = "generate 5 mcqs on Vectorization methods with answers"
response = qa_chain.invoke({"query": question})
print(response["result"])
# Out:
#   Sure! Here are five MCQs related to vectorization methods, along with their answers:
#
# MCQ1: What is the primary advantage of using vectorization techniques in programming?
# A. Improved code readability
# B. Faster execution time
# C. Simplified data manipulation
# D. Better memory management
# Answer: B. Faster execution time
#
# MCQ2: Which of the following vectorization methods is most suitable for performing matrix operations?
# A. Recursion
# B. Iteration
# C. Looping
# D. Function calls
# Answer: C. Looping
#
# MCQ3: What is the purpose of using a hash table in vectorization?
# A. To store data in a sorted order
# B. To reduce memory usage by storing data in an array
# C. To perform fast lookups for elements in a large dataset
# D. To implement recursion in algorithms
# Answer: C. To perform fast lookups for elements in a large dataset
#
# MCQ4: Which of the following vectorization techniques is most efficient for searching an element in a sorted array?
# A. Linear search
# B. Binary search
# C. Iteration through all elements
# D. Recursion
# Answer: B. Binary search
#
# MCQ5: What is the main advantage of using a recursive function to solve a problem?
# A. It reduces memory usage by avoiding arrays
# B. It improves code readability and maintainability
# C. It allows for faster execution time by avoiding loops
# D. It simplifies data manipulation by avoiding complex operations
# Answer: C. It allows for faster execution time by avoiding loops

# %%
question = "generate 30 mcqs on Vectorization methods with answers"
response = qa_chain.invoke({"query": question})
print(response["result"])
# Out:
#   Sure! Here are 30 MCQs on vectorization methods, along with their answers:
#
# 1. What is the main advantage of using vectorization techniques in programming?
# A. Improved code readability
# B. Faster execution time
# C. Simplified code maintenance
# D. Better memory management
# Answer: B
# 2. Which of the following is a key benefit of using array operations in vectorized code?
# A. Reduced memory usage
# B. Improved data manipulation efficiency
# C. Simplified data access patterns
# D. Faster execution time for small arrays
# Answer: B
# 3. What is the primary goal of vectorization in programming?
# A. To reduce the number of loops
# B. To improve code readability
# C. To optimize memory usage
# D. To simplify data manipulation operations
# Answer: A
# 4. Which of the following techniques can be used to perform element-wise arithmetic operations on arrays?
# A. Matrix multiplication
# B. Vector addition
# C. Array concatenation
# D. Loop iteration
# Answer: B
# 5. What is the main advantage of using OpenMP directives in parallel programming?
# A. Improved code readability
# B. Simplified data manipulation operations
# C. Faster execution time for small arrays
# D. Better memory management
# Answer: C
# 6. Which of the following techniques can be used to perform a matrix multiplication operation on two arrays?
# A. Matrix multiplication
# B. Vector addition
# C. Array concatenation
# D. Loop iteration
# Answer: A
# 7. What is the primary goal of using SIMD (Single Instruction Multiple Data) techniques in parallel programming?
# A. To reduce the number of loops
# B. To improve code readability
# C. To optimize memory usage
# D. To simplify data manipulation operations
# Answer: A
# 8. Which of the following techniques can be used to perform a reduction operation on an array?
# A. MPI_Reduce()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: D
# 9. What is the main advantage of using SIMD techniques in parallel programming?
# A. Improved code readability
# B. Faster execution time for small arrays
# C. Simplified data manipulation operations
# D. Better memory management
# Answer: C
# 10. Which of the following techniques can be used to perform a broadcast operation on an array?
# A. MPI_Bcast()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: A
# 11. What is the primary goal of using vectorization techniques in parallel programming?
# A. To reduce the number of loops
# B. To improve code readability
# C. Faster execution time for small arrays
# D. Simplified data manipulation operations
# Answer: A
# 12. Which of the following techniques can be used to perform a reduction operation on an array?
# A. MPI_Reduce()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: D
# 13. What is the main advantage of using OpenMP directives in parallel programming?
# A. Improved code readability
# B. Simplified data manipulation operations
# C. Faster execution time for small arrays
# D. Better memory management
# Answer: C
# 14. Which of the following techniques can be used to perform a broadcast operation on an array?
# A. MPI_Bcast()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: A
# 15. What is the primary goal of using SIMD techniques in parallel programming?
# A. To reduce the number of loops
# B. To improve code readability
# C. Faster execution time for small arrays
# D. Simplified data manipulation operations
# Answer: A
# 16. Which of the following techniques can be used to perform a reduction operation on an array?
# A. MPI_Reduce()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: D
# 17. What is the main advantage of using OpenMP directives in parallel programming?
# A. Improved code readability
# B. Simplified data manipulation operations
# C. Faster execution time for small arrays
# D. Better memory management
# Answer: C
# 18. Which of the following techniques can be used to perform a broadcast operation on an array?
# A. MPI_Bcast()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: A
# 19. What is the primary goal of using vectorization techniques in parallel programming?
# A. To reduce the number of loops
# B. To improve code readability
# C. Faster execution time for small arrays
# D. Simplified data manipulation operations
# Answer: A
# 20. Which of the following techniques can be used to perform a reduction operation on an array?
# A. MPI_Reduce()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: D
# 21. What is the main advantage of using SIMD techniques in parallel programming?
# A. Improved code readability
# B. Faster execution time for small arrays
# C. Simplified data manipulation operations
# D. Better memory management
# Answer: C
# 22. Which of the following techniques can be used to perform a broadcast operation on an array?
# A. MPI_Bcast()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: A
# 23. What is the primary goal of using vectorization techniques in parallel programming?
# A. To reduce the number of loops
# B. To improve code readability
# C. Faster execution time for small arrays
# D. Simplified data manipulation operations
# Answer: A
# 24. Which of the following techniques can be used to perform a reduction operation on an array?
# A. MPI_Reduce()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: D
# 25. What is the main advantage of using OpenMP directives in parallel programming?
# A. Improved code readability
# B. Simplified data manipulation operations
# C. Faster execution time for small arrays
# D. Better memory management
# Answer: C
# 26. Which of the following techniques can be used to perform a broadcast operation on an array?
# A. MPI_Bcast()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: A
# 27. What is the primary goal of using vectorization techniques in parallel programming?
# A. To reduce the number of loops
# B. To improve code readability
# C. Faster execution time for small arrays
# D. Simplified data manipulation operations
# Answer: A
# 28. Which of the following techniques can be used to perform a reduction operation on an array?
# A. MPI_Reduce()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: D
# 29. What is the main advantage of using SIMD techniques in parallel programming?
# A. Improved code readability
# B. Faster execution time for small arrays
# C. Simplified data manipulation operations
# D. Better memory management
# Answer: C
# 30. Which of the following techniques can be used to perform a broadcast operation on an array?
# A. MPI_Bcast()
# B. MPI_Gather()
# C. MPI_Scatter()
# D. MPI_Allreduce()
# Answer: A
#
# I hope these answers help you in your studies!

# %%
question = "generate 10 true/false questions  with answers on Vectorization methods with answers"
response = qa_chain.invoke({"query": question})
print(response["result"])
# Out:
#   Sure! Here are 10 true or false questions related to vectorization methods in parallel computing, along with their answers:
#
# 1. True or False: The Parallel Random Access (PRA) method is a vectorization technique that involves dividing the data into smaller chunks and processing them in parallel. (True)
# 2. True or False: The Data Dependence Graph (DDG) is a graphical representation of the dependencies between variables in a program, which can be used to identify potential parallelism. (False - DDG is actually a technique for analyzing the data dependencies in a program to identify opportunities for parallelization.)
# 3. True or False: The OpenMP compiler generates optimized code by automatically vectorizing loops. (True)
# 4. True or False: The MPI_Allreduce() function in MPI is used for collective operations such as summing the values of all processors. (False - MPI_Allreduce() is actually a function for reducing the values of all processors.)
# 5. True or False: The OpenMP directives #PARALLEL and #DATA_SHARED are used to specify the number of threads that can execute simultaneously. (True)
# 6. True or False: The MPI_Barrier() function in MPI is used to synchronize all processes in a communicator before executing any further operations. (False - MPI_Barrier() is actually a function for blocking all processes until they are ready to proceed.)
# 7. True or False: The OpenMP _omp parallel directive can be used to specify the number of threads that should execute simultaneously. (True)
# 8. True or False: The MPI_Reduce() function in MPI is used for collective operations such as summing the values of all processors. (False - MPI_Reduce() is actually a function for reducing the values of all processors.)
# 9. True or False: The OpenMP _omp critical directive can be used to specify the number of threads that should execute simultaneously. (True)
# 10. True or False: The MPI_Gather() function in MPI is used for collective operations such as summing the values of all processors. (False - MPI_Gather() is actually a function for gathering data from all processes.)

# %%
def setup_qa_chain():
    # Replace with actual setup of the retriever and LLM
    # Here we're assuming you have already initialized knowledge base and LLM
    embeddings = HuggingFaceEmbeddings()
    # Assume knowledge_base and qa_chain are created here
    return qa_chain

# %%
'''def get_input_values():
    # Get user inputs from the terminal
    num_questions = input("Enter the number of questions: ")
    question_type = input("Enter the question type (e.g., TrueorFalse/FillintheBlanks/Mcqs): ")
    difficulty_level = input("Enter the difficulty level (e.g., Easy/Medium/Hard): ")

    # Construct the query using the inputs
    query = f"Generate {num_questions} {question_type} questions with answers on given pdf of {difficulty_level} difficulty."
    
    # Initialize the QA chain
    qa_chain = setup_qa_chain()

    # Run the query through the QA chain
    response = qa_chain.invoke({"query": query})
    
    # Display the result in the terminal
    print("Generated Questions and Answers:")
    print(response["result"])

# Run the function to get inputs and generate questions
get_input_values()'''
# Out:
# 'def get_input_values():\n    # Get user inputs from the terminal\n    num_questions = input("Enter the number of questions: ")\n    question_type = input("Enter the question type (e.g., TrueorFalse/FillintheBlanks/Mcqs): ")\n    difficulty_level = input("Enter the difficulty level (e.g., Easy/Medium/Hard): ")\n\n    # Construct the query using the inputs\n    query = f"Generate {num_questions} {question_type} questions with answers on given pdf of {difficulty_level} difficulty."\n    \n    # Initialize the QA chain\n    qa_chain = setup_qa_chain()\n\n    # Run the query through the QA chain\n    response = qa_chain.invoke({"query": query})\n    \n    # Display the result in the terminal\n    print("Generated Questions and Answers:")\n    print(response["result"])\n\n# Run the function to get inputs and generate questions\nget_input_values()'

# %%
question = "generate 10 fill in the blanks with answers on Vectorization methods with answers"
response = qa_chain.invoke({"query": question})
print(response["result"])
# Out:
#   Sure! Here are 10 fill-in-the-blank questions related to vectorization methods, along with their answers:
#
# 1. What is the primary advantage of using vectorization techniques in parallel computing?
# Answer: Reduced memory usage and improved performance by processing multiple data elements simultaneously.
# 2. Which method of vectorization involves dividing a problem into smaller subproblems that can be solved independently, then combining their results?
# Answer: Divide-and-Conquer Method.
# 3. What is the main advantage of using parallel loops in vectorization?
# Answer: Improved performance by reducing the number of iterations and increasing the processing speed.
# 4. Which method of vectorization involves dividing a problem into smaller parts, solving each part independently, and then combining their results?
# Answer: Parallel Iterative Method.
# 5. What is the main advantage of using OpenMP directives in vectorization?
# Answer: Improved performance by reducing the number of iterations and increasing the processing speed.
# 6. Which method of vectorization involves dividing a problem into smaller parts, solving each part independently, and then combining their results using a reduction operation?
# Answer: Reduction Method.
# 7. What is the main advantage of using MPI for distributed computing in vectorization?
# Answer: Improved performance by allowing multiple processors to work together on a single problem.
# 8. Which method of vectorization involves dividing a problem into smaller parts, solving each part independently, and then combining their results using a broadcast operation?
# Answer: Broadcast Method.
# 9. What is the main advantage of using CUDA for GPU-based vectorization?
# Answer: Improved performance by utilizing the parallel processing capabilities of graphics processing units (GPUs).
# 10. Which method of vectorization involves dividing a problem into smaller parts, solving each part independently, and then combining their results using a recursive function call?
# Answer: Recursive Method.

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.llms import Ollama
from fpdf import FPDF
import os

# Function to save response to a PDF
def save_to_pdf(response, output_file):
    pdf = FPDF()
    pdf.set_auto_page_break(auto=True, margin=15)
    pdf.add_page()
    pdf.set_font("Arial", size=12)
    pdf.multi_cell(0, 10, response)
    pdf.output(output_file)
    print(f"Response saved to {output_file}")

# RAG Setup and PDF Saving
def main():
    # Example response for testing purposes
    # In a real scenario, you will be working with your RAG pipeline to get this result.
    result = response["result"]

    # Get current working directory to save the output PDF
    current_directory = os.getcwd()
    print(f"Saving PDF in directory: {current_directory}")

    # Define the output file name with current directory
    output_file = os.path.join(current_directory, "RAG_Response_Vectorization.pdf")

    # Save result to PDF
    save_to_pdf(result, output_file)

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Saving PDF in directory: c:\Users\Srujana\OneDrive\Desktop\MODEL
# Response saved to c:\Users\Srujana\OneDrive\Desktop\MODEL\RAG_Response_Vectorization.pdf
